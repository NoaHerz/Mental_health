# %%
from cmlreaders import CMLReader, get_data_index
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy
from scipy import stats

# %%
BAI_high = 15
BAI_low = 8
BDI_high = 16
BDI_low = 10

sel_sub = pd.DataFrame([])
master = pd.read_excel(r'./220222_all_neuropsych.xlsx',engine="openpyxl") #read master spreadsheet of all RAM subjects demo/neuropsych data

sub_mat=list(np.zeros(len(master))*np.nan)
df = get_data_index('r1')
# df_select = pd.DataFrame([])
for sub in df['subject'].unique():
    num = int(sub[2:5])
    for i in master.index:
        sel = master.iloc[i]['Subject Number']
        if sel == num:
            sub_mat[i]=sub
# df_select[0:50]
master['subject']=sub_mat

len(master)
# Out:
# 600

# %%
master
# Out:
#      Subject Number                  Event Name                  Study site  \
# 0                 1  Subject Consent & Surgery   University of Pennsylvania
# 1                 2  Subject Consent & Surgery   University of Pennsylvania
# 2                 3  Subject Consent & Surgery   University of Pennsylvania
# 3                 4  Subject Consent & Surgery         Dartmouth University
# 4                 5  Subject Consent & Surgery   University of Pennsylvania
# ..              ...                         ...                         ...
# 595             596  Subject Consent & Surgery              UT Southwestern
# 596             597  Subject Consent & Surgery           Jefferson Hospital
# 597             598  Subject Consent & Surgery             Emory University
# 598             599  Subject Consent & Surgery              UT Southwestern
# 599             600  Subject Consent & Surgery              UT Southwestern
#
#      Gender  Years of Education  Age of seizure onset  \
# 0    Female                13.0                  20.0
# 1    Female                16.0                  34.0
# 2    Female                13.0                  37.0
# 3    Female                12.0                   6.0
# 4    Female                 NaN                   NaN
# ..      ...                 ...                   ...
# 595  Female                12.0                  33.0
# 596    Male                 NaN                   NaN
# 597  Female                12.0                  16.0
# 598    Male                 NaN                   8.0
# 599    Male                15.0                   6.0
#
#      Age at Implant (calculated) Phase II Implant Date  \
# 0                      48.105026            2014-10-08
# 1                      49.383743            2014-11-12
# 2                      39.390382            2014-11-13
# 3                      51.918931            2014-11-06
# 4                      20.304432            2015-01-14
# ..                           ...                   ...
# 595                    35.861106            2021-12-07
# 596                          NaN            2021-12-10
# 597                    39.568346            2021-12-15
# 598                    20.728808            2022-02-04
# 599                    27.896534            2018-03-27
#
#     Phase III Implant Date   \
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
# ..                      ...
# 595                     NaT
# 596                     NaT
# 597                     NaT
# 598                     NaT
# 599              2022-02-07
#
#                     Traumatic Brain Injury (TBI) Notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2    motor vehicle accident due to loss of consciou...
# 3    In early 90s, motor vehicle accident resulting...
# 4                                                  NaN
# ..                                                 ...
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#     Date of Pre-operative Report   BAI   BDI  PHQ-9  GAD-7 FSIQ    GAI  VCI  \
# 0                            NaT   8.0   2.0    NaN    NaN   72   76.0   81
# 1                            NaT   9.0   0.0    NaN    NaN   86   84.0   89
# 2                            NaT   NaN   NaN    NaN    NaN  102    NaN  107
# 3                            NaT   NaN   NaN    NaN    NaN   72    NaN   78
# 4                            NaT   NaN   NaN    NaN    NaN   80   89.0   98
# ..                           ...   ...   ...    ...    ...  ...    ...  ...
# 595                          NaT   NaN   NaN    NaN    NaN   84   87.0    9
# 596                          NaT   NaN   NaN    NaN    NaN  NaN    NaN  NaN
# 597                   2019-02-19  35.0  25.0    NaN    NaN   86   96.0  103
# 598                   2019-06-03   NaN   NaN    NaN    NaN   87  101.0   98
# 599                   2017-06-27   NaN   2.0    NaN    NaN  NaN    NaN  NaN
#
#      PRI  FSIQ (Two Subtest)  FSIQ (Four Subtest)  \
# 0     75                 NaN                  NaN
# 1     84                 NaN                  NaN
# 2    100                 NaN                  NaN
# 3     82                 NaN                  NaN
# 4     82                 NaN                  NaN
# ..   ...                 ...                  ...
# 595    7                 NaN                  NaN
# 596  NaN                 NaN                  NaN
# 597   88                 NaN                  NaN
# 598  104                 NaN                  NaN
# 599   14                 NaN                  NaN
#
#                             Pre-operative Report  \
# 0                          REP001_neurospych.pdf
# 1                          R1002P_neuropsych.pdf
# 2                          R1003P_neuropsych.pdf
# 3                          R1004D Neuropsych.pdf
# 4                          R1005P_neuropsych.pdf
# ..                                           ...
# 595         NeuropsychologicalReport_R1596T.docx
# 596                                          NaN
# 597  R1598E-Neuropsychologic Report_redacted.pdf
# 598                         NP report - 1599.pdf
# 599                       Neuropsych_R1600T.docx
#
#     Prior Neurosurgical Procedures (can select more than one)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595                                          Resection
# 596                                                NaN
# 597                    Laser ablation (i.e. Visualase)
# 598                    Laser ablation (i.e. Visualase)
# 599                VNS implant,RNS implant (Neuropace)
#
#                        Prior Surgery: Resection Detail  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595  WHO Grade 2 left frontal diffuse astrocytoma, ...
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#     Prior Surgery: Callosotomy Detail  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 595                               NaN
# 596                               NaN
# 597                               NaN
# 598                               NaN
# 599                               NaN
#
#                   Prior Surgery: Laser Ablation Detail subject
# 0                                                  NaN  R1001P
# 1                                                  NaN  R1002P
# 2                                                  NaN  R1003P
# 3                                                  NaN  R1004D
# 4                                                  NaN     NaN
# ..                                                 ...     ...
# 595                                                NaN  R1596T
# 596                                                NaN     NaN
# 597  right anterior temporal hippocampus laser abla...  R1598E
# 598  Litt 1 2/2018 Left SMA  Litt 2 11/2018 Mesial ...     NaN
# 599                                                NaN     NaN
#
# [600 rows x 27 columns]

# %%
iq_list = []
dep_list = []
anx_list = []

for i in master.index:
    try:
        if pd.notnull(master.iloc[i]['FSIQ']) == True:
            IQ = master.iloc[i]['FSIQ']
        elif pd.notnull(master.iloc[i]['FSIQ (Four Subtest)']) == True:
            IQ = master.iloc[i]['FSIQ (Four Subtest)']
        elif pd.notnull(master.iloc[i]['GAI']) == True:
            IQ = master.iloc[i]['GAI']
        elif pd.notnull(master.iloc[i]['VCI']) == True:
            IQ = master.iloc[i]['VCI']
        elif pd.notnull(master.iloc[i]['PRI']) == True:
            IQ = master.iloc[i]['PRI']
        else:
            IQ = np.nan
        iq_list.append(IQ)

        if pd.notnull(master.iloc[i]['BDI']) == True:
            dep = master.iloc[i]['BDI']
        elif pd.notnull(master.iloc[i]['PHQ-9']) == True:
            dep = master.iloc[i]['PHQ-9']
        else:
            dep = np.nan
        dep_list.append(dep)
        
        if pd.notnull(master.iloc[i]['BAI']) == True:
            anx = master.iloc[i]['BAI']
        elif pd.notnull(master.iloc[i]['GAD-7']) == True:
            anx = master.iloc[i]['GAD-7']
        else:
            anx = np.nan
        anx_list.append(anx)

    except:
        print(i)
master['IQ'] = iq_list
master['depression'] = dep_list
master['anxiety'] = anx_list
#master[master.depression.apply(lambda x: type(x)) != int]

# %%
pd.set_option('display.max_columns', None)
site_stats = pd.DataFrame([])
tot = 0

#Check how many subjects have all measures out of those that were tested and have a depression measure
for site in master['Study site'].unique():
    site_df = master[master['Study site']==site]
    tested = site_df.dropna(subset=['subject', 'depression'])
    tot = tot + len(tested)
    site_stats=site_stats.append({
        'site':site,
        'total subs':len(site_df),
        'subs tested and have depression score':len(tested),
        'gender':tested['Gender'].count(),
        'years of edu':tested['Years of Education'].count(),
        'age of sz onset':tested['Age of seizure onset'].count(),
        'age at implant':tested['Age at Implant (calculated)'].count(),
        'TBI':tested['Traumatic Brain Injury (TBI) Notes'].count(),
        'BAI':tested['BAI'].count(),
        'BDI':tested['BDI'].count(),
        'PHQ-9':tested['PHQ-9'].count(),
        'GAD-7':tested['GAD-7'].count(),
        'FSIQ4':tested['FSIQ'].count(),
        'GAI':tested['GAI'].count(),
        'VCI':tested['VCI'].count(),
        'PRI':tested['PRI'].count(),
        'FSIQ2':tested['FSIQ (Four Subtest)'].count(),
        'Consolidated IQ':tested['IQ'].count(),
        'Consolidated dep':tested['depression'].count(),
        'Consolidated anx':tested['anxiety'].count(),
        'Neurosurg procedure':tested['Prior Neurosurgical Procedures (can select more than one)'].count()
    }, ignore_index=True)
    
site_stats[['Consolidated IQ', 'Consolidated dep', 'Consolidated anx', 'site', 'subs tested and have depression score']]
# Out:
#    Consolidated IQ  Consolidated dep  Consolidated anx  \
# 0             19.0              20.0               9.0
# 1             39.0              41.0              32.0
# 2             63.0              74.0              73.0
# 3              0.0               0.0               0.0
# 4             39.0              40.0              38.0
# 5              0.0               3.0               0.0
# 6              7.0              16.0               9.0
# 7              1.0               1.0               1.0
# 8              6.0               6.0               3.0
#
#                          site  subs tested and have depression score
# 0  University of Pennsylvania                                   20.0
# 1        Dartmouth University                                   41.0
# 2          Jefferson Hospital                                   74.0
# 3    University of Washington                                    0.0
# 4            Emory University                                   40.0
# 5                 Mayo Clinic                                    3.0
# 6             UT Southwestern                                   16.0
# 7         Columbia University                                    1.0
# 8                       NINDS                                    6.0

# %%
master.columns
# subset = master.dropna(subset=['subject'])
subset = master.dropna(subset=['IQ', 'depression', 'anxiety', 'Years of Education', 'Age at Implant (calculated)', 'Gender', 'Age of seizure onset'])
len(subset)
# Out:
# 142

# %%
trial_df = pd.DataFrame([])
list_df = pd.DataFrame([])

experiments = ['FR1', 'catFR1']

for sub in master['subject']:
#   try:
    for exp in experiments:
        localizations=df[(df['subject']==sub) & (df['experiment']==exp)]['localization'].unique()        

        for loc in localizations:
            montages = df[(df['subject']==sub) & (df['experiment']==exp) & (df['localization']==loc)]['montage'].unique()            

            for mont in montages: # iterate over montages            
                data = df[np.logical_and(df["subject"] == sub, df['experiment']==exp)]
                sessions=data[np.logical_and(data['montage']==mont,data['localization']==loc)]['session'].unique()

                for sess in sessions: 
                    reader = CMLReader(sub, exp, sess, montage=mont, localization=loc)   #reader for loading CML data
                    evs = reader.load('task_events')
                    word_evs = evs[evs['type']=='REC_WORD']

                    #exclude practice lists 
                    lists = len(word_evs['list'][word_evs['list']>0].unique()) 
                    corr_recs = len(word_evs[word_evs['intrusion']==0])
                    ELIs = len(word_evs[word_evs['intrusion']==-1])
                    PLIs = len(word_evs[word_evs['intrusion']>0])
                    total_ints = ELIs + PLIs
                    total_trials = corr_recs + total_ints

                    trials = [] #make list of event numbers of analysis
                    for list_num in word_evs['list'][word_evs['list']>0].unique():
                        list_events=word_evs[word_evs['list']==list_num]
                        if len(list_events)>0: 
                            for i in range(0,len(list_events)):
                                trials.append(list_events.index[i])
#                         PLI = len(list_events[list_events['intrusion']>0])
#                         ELI = len(list_events[list_events['intrusion']==-1])
#                         correc = len(list_events[list_events['intrusion']==0])
#                         list_df = list_df.append({ #create dataframe of events for analysis grouped by list ##should I filter out lists with no events?
#                             'subject':sub,
#                             'session': sess,
#                             'experiment': exp,
#                             'list': list_num,
#                             'number of correct recalls': correc,
#                             'number of extra-list intrusions': ELI,
#                             'number of prior-list intrusions': PLI,
#                             'total number of intrusions': ELI+PLI,
#                             'BAI':BAI,
#                             'BDI':BDI
#                             },ignore_index=True)
#                     row = master[master['subject']==sub] #get row of BAI/BDI scores for subject
#                     BAI = row['BAI'].item()
#                     BDI = row['BDI'].item()
                    trial_df = trial_df.append({ #create dataframe of events for analysis grouped by session
                        'subject':sub,
                        'session': sess,
                        'montage': mont,
                        'localization': loc,
                        'experiment': exp,
                        'number of lists': lists,
                        'number of correct recalls': corr_recs,
                        'number of extra-list intrusions': ELIs,
                        'number of prior-list intrusions': PLIs,
                        'total number of intrusions': total_ints,
                        'total number of trials left': total_trials,
                        'trials for analysis': trials
                        },ignore_index=True) 
#     except:
#         print('Failed for subject:', sub)
trial_df[:100]
# Out:
#    experiment  localization  montage  number of correct recalls  \
# 0         FR1           0.0      0.0                       62.0
# 1         FR1           0.0      0.0                       63.0
# 2         FR1           0.0      0.0                      117.0
# 3         FR1           0.0      0.0                      120.0
# 4         FR1           0.0      0.0                       86.0
# ..        ...           ...      ...                        ...
# 95        FR1           0.0      0.0                       45.0
# 96        FR1           0.0      0.0                      102.0
# 97        FR1           0.0      0.0                      109.0
# 98     catFR1           0.0      0.0                       99.0
# 99     catFR1           0.0      0.0                       17.0
#
#     number of extra-list intrusions  number of lists  \
# 0                              21.0             22.0
# 1                              19.0             23.0
# 2                               3.0             25.0
# 3                               2.0             25.0
# 4                              30.0             22.0
# ..                              ...              ...
# 95                              6.0             11.0
# 96                             13.0             24.0
# 97                             11.0             24.0
# 98                             22.0             25.0
# 99                             10.0              8.0
#
#     number of prior-list intrusions  session subject  \
# 0                              25.0      0.0  R1001P
# 1                              17.0      1.0  R1001P
# 2                               8.0      0.0  R1002P
# 3                               3.0      1.0  R1002P
# 4                              26.0      0.0  R1003P
# ..                              ...      ...     ...
# 95                              2.0      1.0  R1066P
# 96                             14.0      2.0  R1066P
# 97                              8.0      3.0  R1066P
# 98                             13.0      0.0  R1066P
# 99                              1.0      1.0  R1066P
#
#     total number of intrusions  total number of trials left  \
# 0                         46.0                        108.0
# 1                         36.0                         99.0
# 2                         11.0                        128.0
# 3                          5.0                        125.0
# 4                         56.0                        142.0
# ..                         ...                          ...
# 95                         8.0                         53.0
# 96                        27.0                        129.0
# 97                        19.0                        128.0
# 98                        35.0                        134.0
# 99                        11.0                         28.0
#
#                                   trials for analysis
# 0   [63, 64, 66, 67, 88, 89, 90, 91, 92, 93, 95, 9...
# 1   [38, 39, 40, 41, 62, 63, 64, 65, 66, 67, 68, 8...
# 2   [38, 39, 40, 41, 67, 68, 69, 70, 71, 74, 95, 9...
# 3   [38, 39, 40, 41, 42, 43, 44, 65, 66, 67, 68, 6...
# 4   [38, 39, 40, 41, 42, 44, 46, 48, 69, 70, 71, 7...
# ..                                                ...
# 95  [38, 39, 41, 42, 63, 64, 65, 66, 67, 68, 69, 9...
# 96  [39, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 7...
# 97  [39, 40, 41, 42, 43, 44, 66, 67, 69, 70, 92, 9...
# 98  [39, 40, 41, 43, 44, 45, 46, 69, 70, 72, 73, 7...
# 99  [82, 83, 104, 107, 108, 109, 110, 111, 133, 13...
#
# [100 rows x 12 columns]

# %%
# master[master['subject']=='R1001P']['Phase III Implant Date'].item()
master.columns
# Out:
# Index(['Subject Number', 'Event Name', 'Study site', 'Gender',
#        'Years of Education', 'Age of seizure onset',
#        'Age at Implant (calculated)', 'Phase II Implant Date',
#        'Phase III Implant Date ', 'Traumatic Brain Injury (TBI) Notes',
#        'Date of Pre-operative Report', 'BAI', 'BDI', 'PHQ-9', 'GAD-7', 'FSIQ',
#        'GAI', 'VCI', 'PRI', 'FSIQ (Two Subtest)', 'FSIQ (Four Subtest)',
#        'Pre-operative Report',
#        'Prior Neurosurgical Procedures (can select more than one)',
#        'Prior Surgery: Resection Detail', 'Prior Surgery: Callosotomy Detail',
#        'Prior Surgery: Laser Ablation Detail', 'subject', 'IQ', 'depression',
#        'anxiety'],
#       dtype='object')

# %%
#BEGINNING OF SESSION LEVEL ANALYSES (?)
df_master = pd.DataFrame([])
#Create master dataframe of important session stats, demographics, and neuropsych.
for i in trial_df.index:
    try:
        sub = trial_df.iloc[i]['subject']
        eli = trial_df.iloc[i]['number of extra-list intrusions']
        pli = trial_df.iloc[i]['number of prior-list intrusions']
        correc = trial_df.iloc[i]['number of correct recalls']
        allrec = trial_df.iloc[i]['total number of trials left']
        lists = trial_df.iloc[i]['number of lists']
        session=trial_df.iloc[i]['session']
        exp = trial_df.iloc[i]['experiment']
        PLI_avg = float(pli/lists) #average per list
        ELI_avg = float(eli/lists)
        correc_avg = float(correc/lists)
        allrec_avg = float(allrec/lists)
        if allrec > 0: #remove sessions with no valid recalls and no BAI or BDI
            df_master = df_master.append({
                'subject':sub,
                'experiment':exp,
                'correct recalls':correc,
                'ELIs':eli,
                'PLIs':pli,
                'total ints': eli+pli,
                'lists':lists,
                'session':session,
                'all recalls':allrec,
                'average_correct_recalls':correc_avg,
                'average_total_recalls':allrec_avg,
                'average_ELI':ELI_avg,
                'average_PLI':PLI_avg,
                'average_total_ints':ELI_avg+PLI_avg,
                'BAI':master[master['subject']==sub]['BAI'].item(),
                'BDI':master[master['subject']==sub]['BDI'].item(),
                'site':master[master['subject']==sub]['Study site'].item(),
                'gender':master[master['subject']==sub]['Gender'].item(),
                'years_of_education':master[master['subject']==sub]['Years of Education'].item(),
                'age_of_seizure_onset':master[master['subject']==sub]['Age of seizure onset'].item(),
                'age_at_implant':master[master['subject']==sub]['Age at Implant (calculated)'].item(),
                'implant_date':master[master['subject']==sub]['Phase II Implant Date'].item(),
                'reimplant_date':master[master['subject']==sub]['Phase III Implant Date '].item(),
                'TBI_notes':master[master['subject']==sub]['Traumatic Brain Injury (TBI) Notes'].item(),
                'date_of_neuropsych_report':master[master['subject']==sub]['Date of Pre-operative Report'].item(),
                'comb_IQ':master[master['subject']==sub]['IQ'].item(),
                'depression':master[master['subject']==sub]['depression'].item(),
                'anxiety':master[master['subject']==sub]['anxiety'].item(),
                'FSIQ4':master[master['subject']==sub]['FSIQ'].item(),
                'GAI':master[master['subject']==sub]['GAI'].item(),
                'VCI':master[master['subject']==sub]['VCI'].item(),
                'PRI':master[master['subject']==sub]['PRI'].item(),
                'FSIQ2':master[master['subject']==sub]['FSIQ (Four Subtest)'].item(),
                'PHQ-9':master[master['subject']==sub]['PHQ-9'].item(),
                'GAD-7':master[master['subject']==sub]['GAD-7'].item(),
                'binary_prior_neuro': master[master['subject']==sub]['Prior Neurosurgical Procedures (can select more than one)'].item()=='nan', 
                'prior_neurosurgical_procedures':master[master['subject']==sub]['Prior Neurosurgical Procedures (can select more than one)'].item(),    
            }, ignore_index = True)
        else:
            print('removed row =', i, sub, exp, 'due to no valid recalls')
    except:
        print('failed for row =', i, sub, exp)
# df_master = df_master.dropna(subset=['BAI', 'BDI'], how='all') #drop sessions from subjects that have neither score
df_master[:50]

# %%
len(df_master)
# Out:
# 1104

# %%
sub_ar = df_master['subject'].unique()
res = sum(1 for i in sub_ar if "J" in i)
# sub_ar
res
# Out:
# 63

# %% [markdown]
#  # Linear mixed effects model

# %%
# Compare models using a liklihood-ratio test :
from scipy import stats
import statsmodels.api as sm

def lrtest(llmin, llmax,df = 1):
    lr = 2 * (llmax - llmin)
    if llmax<llmin:
        raise ValueError('Check assumptions.')
    stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
    p = stats.chisqprob(lr, df) 
    return lr, p

# %% [markdown]
# The bellow statistics checks for experiment main effect (catFR/FR) on the total number of intrusions (not sig) and correct-recllas (catFR produce more correct recalls compared to FR)

# %%
vc = {'session': '0 + C(session)'} #the vc formula always varies within the groups parameter, so it will vary within subject 
# If we want to use list as another nested variable, we can use this:
# vc = {'session': '0 + C(session)', 'list': '0 + C(list):C(session)'}

## Total number of intrusions:
model = sm.MixedLM.from_formula('average_total_ints ~ 1',vc_formula=vc,  groups='subject', data=df_master) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# Experiment main effect
model = sm.MixedLM.from_formula('average_total_ints ~ C(experiment)',vc_formula=vc, groups='subject', data=df_master) 
result=model.fit(reml=False, method='nm')
llf_exp =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of experiment on total intrusions')
lr, p = lrtest(llf_empty, llf_exp, df = 1) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))

## Total number of correct-recalls:
model = sm.MixedLM.from_formula('average_correct_recalls ~ 1',vc_formula=vc,  groups='subject', data=df_master) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# Experiment main effect
model = sm.MixedLM.from_formula('average_correct_recalls ~ C(experiment)',vc_formula=vc, groups='subject', data=df_master) 
result=model.fit(reml=False, method='nm')
llf_exp =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects of experiment on correct-recalls
print('Main effect of experiment on correct-recalls')
lr, p = lrtest(llf_empty, llf_exp, df = 1) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-213-fa114e687a83> in <module>
#       4
#       5 ## Total number of intrusions:
# ----> 6 model = sm.MixedLM.from_formula('average_total_ints ~ 1',vc_formula=vc,  groups='subject', data=df_master)
#       7 result=model.fit(reml=False, method='nm')
#       8 llf_empty =result.llf #log likelihood
#
# ~/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in from_formula(cls, formula, data, re_formula, vc_formula, subset, use_sparse, missing, *args, **kwargs)
#    1023         kwargs["groups"] = groups
#    1024         mod = super(MixedLM, cls).from_formula(
# -> 1025             formula, data, *args, **kwargs)
#    1026
#    1027         # expand re names to account for pairs of RE
#
# ~/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     192                        'formula': formula,  # attach formula for unpckling
#     193                        'design_info': design_info})
# --> 194         mod = cls(endog, exog, *args, **kwargs)
#     195         mod.formula = formula
#     196
#
# ~/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in __init__(self, endog, exog, groups, exog_re, exog_vc, use_sqrt, missing, **kwargs)
#     776
#     777         # Split the data by groups
# --> 778         self.endog_li = self.group_list(self.endog)
#     779         self.exog_li = self.group_list(self.exog)
#     780         self.exog_re_li = self.group_list(self.exog_re)
#
# ~/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in group_list(self, array)
#    1081         if array.ndim == 1:
#    1082             return [np.array(array[self.row_indices[k]])
# -> 1083                     for k in self.group_labels]
#    1084         else:
#    1085             return [np.array(array[self.row_indices[k], :])
#
# ~/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in <listcomp>(.0)
#    1081         if array.ndim == 1:
#    1082             return [np.array(array[self.row_indices[k]])
# -> 1083                     for k in self.group_labels]
#    1084         else:
#    1085             return [np.array(array[self.row_indices[k], :])
#
# IndexError: index 1103 is out of bounds for axis 0 with size 1103

# %%
df_master.columns
# Out:
# Index(['BAI', 'BDI', 'ELIs', 'FSIQ2', 'FSIQ4', 'GAD-7', 'GAI', 'PHQ-9', 'PLIs',
#        'PRI', 'TBI_notes', 'VCI', 'age_at_implant', 'age_of_seizure_onset',
#        'all recalls', 'anxiety', 'average_ELI', 'average_PLI',
#        'average_correct_recalls', 'average_total_ints',
#        'average_total_recalls', 'binary_prior_neuro', 'comb_IQ',
#        'correct recalls', 'date_of_neuropsych_report', 'depression',
#        'experiment', 'gender', 'implant_date', 'lists',
#        'prior_neurosurgical_procedures', 'reimplant_date', 'session', 'site',
#        'subject', 'total ints', 'years_of_education'],
#       dtype='object')

# %% [markdown]
# Let's start with a simple model that predicts intrusions/correct-reclls based on BAI+BDI scores (without other factors)
#
# (We won't really report these results...)

# %%
## Total number of intrusions:

df_BAI_BDI_reduced=df_master.dropna(axis='index',subset=['BDI','BAI'])

model = sm.MixedLM.from_formula('average_total_ints ~ 1',vc_formula=vc,  groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# BDI+BAI variables - main effect
model = sm.MixedLM.from_formula('average_total_ints ~ BDI+BAI',vc_formula=vc, groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of BAI+BDI on total intrusions')
lr, p = lrtest(llf_empty, llf_demog, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


## Total number of correct-recalls:

model = sm.MixedLM.from_formula('average_correct_recalls ~ 1',vc_formula=vc,  groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# BDI+BAI variables - main effect
model = sm.MixedLM.from_formula('average_correct_recalls ~ BDI+BAI',vc_formula=vc, groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of BAI+BDI on total corecl-recalls:')
lr, p = lrtest(llf_empty, llf_demog, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.2367
# Min. group size:  1       Log-Likelihood:     -484.5992
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      1.000      0.046   21.969   0.000    0.911    1.089
# session Var    0.489      0.285
# ================================================================
#
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.2385
# Min. group size:  1       Log-Likelihood:     -481.6306
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      0.869      0.077   11.268   0.000    0.717    1.020
# BDI            0.000      0.006    0.012   0.990   -0.011    0.011
# BAI            0.012      0.006    2.117   0.034    0.001    0.023
# session Var    0.474      0.281
# ================================================================
#
# Main effect of BAI+BDI on total intrusions
# LR test, p value: 5.9370, 0.051379154723111823688252997044
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:            MixedLM Dependent Variable: average_correct_recalls
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              2.4231
# Min. group size:  1       Log-Likelihood:     -791.6348
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------------
#                 Coef.    Std.Err.      z       P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------
# Intercept       3.952       0.090    43.715    0.000     3.775     4.129
# session Var     0.665       0.351
# =====================================================================
#
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:            MixedLM Dependent Variable: average_correct_recalls
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              2.3126
# Min. group size:  1       Log-Likelihood:     -787.1525
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------------
#                Coef.     Std.Err.      z       P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------
# Intercept       3.997       0.152    26.294    0.000     3.699     4.295
# BDI            -0.031       0.011    -2.753    0.006    -0.053    -0.009
# BAI             0.028       0.012     2.443    0.015     0.006     0.051
# session Var     0.712       0.337
# =====================================================================
#
# Main effect of BAI+BDI on total corecl-recalls:
# LR test, p value: 8.9645, 0.011307894366023441348745315338

# %% [markdown]
# These results indicate that:
# Higher BAI scores are associated with both more intrusions and more correct-reclls (suggesting that they have a more liberal threshorld for recalling words...?)
# Higher BDI scores are associated with less correct recalls
#
# Overall, BAI and BDI scores are significant predictors of the number of correct-recalls (trending significance for the number of intrusions)

# %% [markdown]
# We can also predict PLIs/ELIs based on BDI+BAI score:

# %%
##  number of PL intrusions:

df_BAI_BDI_reduced=df_master.dropna(axis='index',subset=['BDI','BAI'])

model = sm.MixedLM.from_formula('average_PLI ~ 1',vc_formula=vc,  groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# BDI+BAI variables - main effect
model = sm.MixedLM.from_formula('average_PLI ~ BAI+BDI',vc_formula=vc, groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_recall =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of BAI+BDI on average_PLI')
lr, p = lrtest(llf_empty, llf_recall, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))

##  number of EL intrusions:

model = sm.MixedLM.from_formula('average_ELI ~ 1',vc_formula=vc,  groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# BDI+BAI variables - main effect
model = sm.MixedLM.from_formula('average_ELI ~ BAI+BDI',vc_formula=vc, groups='subject', data=df_BAI_BDI_reduced) 
result=model.fit(reml=False, method='nm')
llf_recall =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of BAI+BDI on average_ELI')
lr, p = lrtest(llf_empty, llf_recall, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: average_PLI
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.0919
# Min. group size:  1       Log-Likelihood:     -267.4346
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------
#                 Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.517    0.026 19.791 0.000  0.465  0.568
# session Var     0.148    0.155
# =========================================================
#
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: average_PLI
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.0939
# Min. group size:  1       Log-Likelihood:     -257.8087
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.394    0.043  9.108 0.000  0.309  0.478
# BAI             0.013    0.003  4.110 0.000  0.007  0.020
# BDI            -0.002    0.003 -0.560 0.576 -0.008  0.004
# session Var     0.133    0.148
# =========================================================
#
# Main effect of BAI+BDI on average_PLI
# LR test, p value: 19.2518, 0.000065998479447840546958416186
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: average_ELI
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.0864
# Min. group size:  1       Log-Likelihood:     -287.4381
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------
#                 Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.483    0.028 17.339 0.000  0.429  0.538
# session Var     0.185    0.175
# =========================================================
#
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: average_ELI
# No. Observations: 400     Method:             ML
# No. Groups:       119     Scale:              0.0863
# Min. group size:  1       Log-Likelihood:     -287.2861
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.473    0.048  9.943 0.000  0.380  0.567
# BAI            -0.001    0.004 -0.309 0.757 -0.008  0.006
# BDI             0.002    0.003  0.550 0.582 -0.005  0.009
# session Var     0.185    0.174
# =========================================================
#
# Main effect of BAI+BDI on average_ELI
# LR test, p value: 0.3040, 0.858982836888420586696213376854

# %% [markdown]
# These results suggest that:
#     Higher BAI scores are associated specifically with more PLIs (and not ELIs)

# %% [markdown]
# Here I predict the rate of intrusions/correct-recalls, based on: sex, prior resection, years of education, age at seizure onset, age of the patient, and general intelligence score (We can change these factors, but I chose here the ones that seemed the most relevant).
#
# I then compare this model to a model that also includes BDI+BAI scores, to see whether those contribute to intrusions prediction/correct-recalls beyond these factors.
#
# Note: the model cannot accept nan values. For each variable that has nan, we are loosing the whole subject, so for these variables let's try and maximize the data we have available. Currently only n=148 have the full data (with all demographic variables)

# %%
# demographic factors main effect on the total number of intrusions (not sig) and correct-recllas (catFR produce more correct recalls compared to FR)

list_demographics_columns=['years_of_education','age_of_seizure_onset','age_at_implant','comb_IQ','BDI','BAI'] #GAI/FSIQ


# Total number of intrusions
# remove nan's from df:
df_master_reduced=df_master.dropna(axis='index',subset=list_demographics_columns)

## Total number of intrusions:
model = sm.MixedLM.from_formula('average_total_ints ~ 1',vc_formula=vc,  groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# demographis variables - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + comb_IQ',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of demographics on total intrusions')
lr, p = lrtest(llf_empty, llf_demog, df = 5) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


# demographis variables + BDI+BAI - main effect ()
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + comb_IQ + BAI + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI/BAI
print('Main effect of BAI+BDI on total intrusions, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


## Total number of correct-recalls:
model = sm.MixedLM.from_formula('average_correct_recalls ~ 1',vc_formula=vc,  groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# demographis variables - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_correct_recalls ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + comb_IQ',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of demographics on number of correct-recalls')
lr, p = lrtest(llf_empty, llf_demog, df = 5) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


# demographis variables + BDI+BAI - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_correct_recalls ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + comb_IQ + BAI + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI/BAI
print('Main effect of BAI+BDI on correct-recalls, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 293     Method:             ML
# No. Groups:       90      Scale:              0.2442
# Min. group size:  1       Log-Likelihood:     -362.7079
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.3
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      0.965      0.056   17.354   0.000    0.856    1.074
# session Var    0.534      0.339
# ================================================================
#
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:             MixedLM  Dependent Variable:  average_total_ints
# No. Observations:  293      Method:              ML
# No. Groups:        90       Scale:               0.2271
# Min. group size:   1        Log-Likelihood:      -264.0603
# Max. group size:   10       Converged:           Yes
# Mean group size:   3.3
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 0.993    0.517  1.922 0.055 -0.020  2.006
# C(gender)[T.Male]         0.267    0.124  2.160 0.031  0.025  0.509
# comb_IQ[T.72.0]          -0.743    0.455 -1.635 0.102 -1.634  0.148
# comb_IQ[T.73.0]          -0.900    0.472 -1.908 0.056 -1.824  0.025
# comb_IQ[T.74.0]           0.043    0.458  0.093 0.926 -0.855  0.940
# comb_IQ[T.75.0]          -1.242    0.418 -2.971 0.003 -2.061 -0.422
# comb_IQ[T.76.0]          -0.376    0.418 -0.899 0.369 -1.195  0.444
# comb_IQ[T.77]             0.609    0.484  1.258 0.208 -0.339  1.557
# comb_IQ[T.78]            -0.558    0.703 -0.793 0.428 -1.936  0.821
# comb_IQ[T.79]            -0.614    0.532 -1.155 0.248 -1.656  0.428
# comb_IQ[T.80]            -0.233    0.406 -0.573 0.567 -1.029  0.563
# comb_IQ[T.81.0]          -0.988    0.425 -2.322 0.020 -1.822 -0.154
# comb_IQ[T.83.0]           0.362    0.416  0.871 0.384 -0.453  1.178
# comb_IQ[T.84.0]          -0.738    0.436 -1.693 0.090 -1.592  0.116
# comb_IQ[T.85]            -0.049    0.432 -0.114 0.909 -0.895  0.797
# comb_IQ[T.86.0]          -0.831    0.411 -2.024 0.043 -1.636 -0.026
# comb_IQ[T.87.0]          -1.237    0.394 -3.140 0.002 -2.009 -0.465
# comb_IQ[T.89.0]          -0.982    0.421 -2.331 0.020 -1.809 -0.156
# comb_IQ[T.91.0]          -0.701    0.511 -1.373 0.170 -1.702  0.300
# comb_IQ[T.92.0]          -0.579    0.421 -1.376 0.169 -1.404  0.246
# comb_IQ[T.94.0]          -0.899    0.468 -1.920 0.055 -1.817  0.019
# comb_IQ[T.95]            -1.654    0.542 -3.053 0.002 -2.716 -0.592
# comb_IQ[T.96.0]          -1.071    0.404 -2.648 0.008 -1.863 -0.278
# comb_IQ[T.98.0]          -1.315    0.503 -2.614 0.009 -2.300 -0.329
# comb_IQ[T.99.0]          -0.917    0.529 -1.735 0.083 -1.953  0.119
# comb_IQ[T.100.0]         -0.502    0.411 -1.223 0.221 -1.307  0.303
# comb_IQ[T.101.0]          1.185    0.474  2.500 0.012  0.256  2.113
# comb_IQ[T.102.0]         -0.759    0.443 -1.714 0.087 -1.627  0.109
# comb_IQ[T.103.0]         -1.067    0.425 -2.510 0.012 -1.900 -0.234
# comb_IQ[T.104]           -0.726    0.490 -1.484 0.138 -1.686  0.233
# comb_IQ[T.105.0]         -1.377    0.422 -3.262 0.001 -2.204 -0.550
# comb_IQ[T.107.0]          0.046    0.420  0.109 0.914 -0.778  0.869
# comb_IQ[T.111.0]         -1.667    0.668 -2.494 0.013 -2.977 -0.357
# comb_IQ[T.114.0]         -1.402    0.470 -2.982 0.003 -2.323 -0.480
# comb_IQ[T.115.0]         -0.099    0.524 -0.189 0.850 -1.126  0.928
# comb_IQ[T.117.0]         -1.226    0.520 -2.358 0.018 -2.244 -0.207
# comb_IQ[T.118.0]         -1.007    0.556 -1.809 0.070 -2.097  0.084
# comb_IQ[T.122.0]         -1.333    0.455 -2.928 0.003 -2.225 -0.441
# comb_IQ[T.32 (prorated)] -1.047    0.509 -2.055 0.040 -2.045 -0.048
# years_of_education        0.004    0.031  0.117 0.907 -0.058  0.065
# age_of_seizure_onset      0.011    0.005  2.183 0.029  0.001  0.020
# age_at_implant            0.008    0.007  1.165 0.244 -0.005  0.022
# session Var               0.138    0.137
# ===================================================================
#
# Main effect of demographics on total intrusions
# LR test, p value: 197.2953, 0.000000000000000000000000000000
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:             MixedLM  Dependent Variable:  average_total_ints
# No. Observations:  293      Method:              ML
# No. Groups:        90       Scale:               0.2239
# Min. group size:   1        Log-Likelihood:      -261.5453
# Max. group size:   10       Converged:           Yes
# Mean group size:   3.3
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept                 1.106    0.515  2.148 0.032  0.097  2.115
# C(gender)[T.Male]         0.246    0.129  1.908 0.056 -0.007  0.499
# comb_IQ[T.72.0]          -0.793    0.452 -1.755 0.079 -1.678  0.093
# comb_IQ[T.73.0]          -0.975    0.469 -2.077 0.038 -1.895 -0.055
# comb_IQ[T.74.0]          -0.143    0.469 -0.305 0.760 -1.062  0.776
# comb_IQ[T.75.0]          -1.274    0.417 -3.058 0.002 -2.091 -0.458
# comb_IQ[T.76.0]          -0.486    0.418 -1.163 0.245 -1.304  0.333
# comb_IQ[T.77]             0.490    0.483  1.015 0.310 -0.456  1.436
# comb_IQ[T.78]            -0.513    0.700 -0.733 0.464 -1.885  0.859
# comb_IQ[T.79]            -0.474    0.537 -0.883 0.377 -1.527  0.579
# comb_IQ[T.80]            -0.189    0.413 -0.457 0.648 -0.998  0.621
# comb_IQ[T.81.0]          -1.009    0.427 -2.363 0.018 -1.847 -0.172
# comb_IQ[T.83.0]           0.349    0.420  0.831 0.406 -0.475  1.173
# comb_IQ[T.84.0]          -0.683    0.436 -1.568 0.117 -1.536  0.171
# comb_IQ[T.85]            -0.005    0.444 -0.011 0.991 -0.875  0.865
# comb_IQ[T.86.0]          -0.820    0.409 -2.007 0.045 -1.620 -0.019
# comb_IQ[T.87.0]          -1.212    0.400 -3.026 0.002 -1.996 -0.427
# comb_IQ[T.89.0]          -0.934    0.434 -2.154 0.031 -1.784 -0.084
# comb_IQ[T.91.0]          -0.704    0.508 -1.386 0.166 -1.700  0.292
# comb_IQ[T.92.0]          -0.470    0.425 -1.106 0.269 -1.302  0.362
# comb_IQ[T.94.0]          -0.870    0.476 -1.828 0.068 -1.802  0.063
# comb_IQ[T.95]            -1.542    0.540 -2.853 0.004 -2.601 -0.483
# comb_IQ[T.96.0]          -1.082    0.410 -2.635 0.008 -1.886 -0.277
# comb_IQ[T.98.0]          -1.214    0.500 -2.426 0.015 -2.195 -0.233
# comb_IQ[T.99.0]          -0.888    0.526 -1.688 0.091 -1.918  0.143
# comb_IQ[T.100.0]         -0.488    0.415 -1.175 0.240 -1.300  0.325
# comb_IQ[T.101.0]          1.332    0.475  2.803 0.005  0.401  2.264
# comb_IQ[T.102.0]         -0.705    0.442 -1.594 0.111 -1.571  0.162
# comb_IQ[T.103.0]         -0.996    0.434 -2.296 0.022 -1.845 -0.146
# comb_IQ[T.104]           -0.828    0.549 -1.507 0.132 -1.904  0.249
# comb_IQ[T.105.0]         -1.355    0.438 -3.092 0.002 -2.214 -0.496
# comb_IQ[T.107.0]          0.081    0.418  0.194 0.846 -0.738  0.900
# comb_IQ[T.111.0]         -1.622    0.663 -2.447 0.014 -2.921 -0.323
# comb_IQ[T.114.0]         -1.245    0.475 -2.619 0.009 -2.177 -0.313
# comb_IQ[T.115.0]         -0.110    0.523 -0.209 0.834 -1.135  0.916
# comb_IQ[T.117.0]         -1.149    0.517 -2.224 0.026 -2.161 -0.136
# comb_IQ[T.118.0]         -0.957    0.557 -1.719 0.086 -2.049  0.134
# comb_IQ[T.122.0]         -1.254    0.455 -2.755 0.006 -2.146 -0.362
# comb_IQ[T.32 (prorated)] -1.219    0.530 -2.298 0.022 -2.258 -0.179
# years_of_education       -0.012    0.032 -0.368 0.713 -0.075  0.051
# age_of_seizure_onset      0.008    0.005  1.565 0.118 -0.002  0.018
# age_at_implant            0.012    0.007  1.663 0.096 -0.002  0.027
# BAI                       0.014    0.008  1.811 0.070 -0.001  0.029
# BDI                      -0.013    0.007 -1.977 0.048 -0.026 -0.000
# session Var               0.135    0.133
# ===================================================================
#
# Main effect of BAI+BDI on total intrusions, beyond other demographic variables:
# LR test, p value: 5.0299, 0.080868776495228597567255235390
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:            MixedLM Dependent Variable: average_correct_recalls
# No. Observations: 293     Method:             ML
# No. Groups:       90      Scale:              2.2282
# Min. group size:  1       Log-Likelihood:     -557.2909
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.3
# ------------------------------------------------------------------------
#                 Coef.    Std.Err.      z       P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------
# Intercept       3.760       0.097    38.586    0.000     3.569     3.951
# session Var     0.411       0.262
# =====================================================================
# /home1/evsnyder/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:            MixedLM Dependent Variable: average_correct_recalls
# No. Observations: 293     Method:             ML
# No. Groups:       90      Scale:              1.4269
# Min. group size:  1       Log-Likelihood:     -467.8283
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.3
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                  -0.502    1.005 -0.499 0.618 -2.471  1.467
# C(gender)[T.Male]          -0.334    0.233 -1.434 0.152 -0.790  0.123
# comb_IQ[T.72.0]             1.261    0.896  1.408 0.159 -0.495  3.017
# comb_IQ[T.73.0]             2.181    0.931  2.344 0.019  0.357  4.005
# comb_IQ[T.74.0]             2.189    0.876  2.500 0.012  0.473  3.906
# comb_IQ[T.75.0]             3.451    0.815  4.236 0.000  1.854  5.047
# comb_IQ[T.76.0]             2.158    0.804  2.682 0.007  0.581  3.734
# comb_IQ[T.77]               3.038    0.947  3.207 0.001  1.181  4.895
# comb_IQ[T.78]               1.644    1.391  1.182 0.237 -1.082  4.369
# comb_IQ[T.79]               1.504    1.044  1.441 0.149 -0.541  3.550
# comb_IQ[T.80]               2.051    0.795  2.581 0.010  0.493  3.608
# comb_IQ[T.81.0]             2.314    0.838  2.762 0.006  0.672  3.957
# comb_IQ[T.83.0]             2.332    0.811  2.876 0.004  0.743  3.920
# comb_IQ[T.84.0]             1.210    0.861  1.405 0.160 -0.478  2.897
# comb_IQ[T.85]               1.637    0.849  1.929 0.054 -0.026  3.301
# comb_IQ[T.86.0]             3.219    0.800  4.021 0.000  1.650  4.787
# comb_IQ[T.87.0]             3.022    0.767  3.938 0.000  1.518  4.526
# comb_IQ[T.89.0]             2.107    0.824  2.557 0.011  0.492  3.722
# comb_IQ[T.91.0]             2.479    1.007  2.461 0.014  0.504  4.453
# comb_IQ[T.92.0]             1.732    0.824  2.102 0.036  0.117  3.347
# comb_IQ[T.94.0]             1.819    0.887  2.051 0.040  0.081  3.558
# comb_IQ[T.95]               3.363    1.062  3.165 0.002  1.280  5.445
# comb_IQ[T.96.0]             3.234    0.794  4.071 0.000  1.677  4.791
# comb_IQ[T.98.0]             3.509    0.992  3.536 0.000  1.564  5.455
# comb_IQ[T.99.0]             2.242    0.992  2.259 0.024  0.297  4.186
# comb_IQ[T.100.0]            2.648    0.795  3.329 0.001  1.089  4.207
# comb_IQ[T.101.0]            1.395    0.917  1.522 0.128 -0.402  3.192
# comb_IQ[T.102.0]            2.037    0.858  2.375 0.018  0.356  3.718
# comb_IQ[T.103.0]            2.716    0.832  3.263 0.001  1.084  4.347
# comb_IQ[T.104]              1.572    0.964  1.632 0.103 -0.316  3.461
# comb_IQ[T.105.0]            3.482    0.823  4.231 0.000  1.869  5.095
# comb_IQ[T.107.0]            3.066    0.828  3.702 0.000  1.442  4.689
# comb_IQ[T.111.0]            4.913    1.201  4.090 0.000  2.558  7.268
# comb_IQ[T.114.0]            5.169    0.906  5.706 0.000  3.393  6.944
# comb_IQ[T.115.0]            3.006    1.002  3.000 0.003  1.042  4.969
# comb_IQ[T.117.0]            2.496    1.023  2.440 0.015  0.491  4.500
# comb_IQ[T.118.0]            2.965    1.044  2.838 0.005  0.918  5.012
# comb_IQ[T.122.0]            3.327    0.871  3.819 0.000  1.619  5.034
# comb_IQ[T.32 (prorated)]    1.498    1.004  1.491 0.136 -0.471  3.466
# years_of_education          0.219    0.060  3.656 0.000  0.101  0.336
# age_of_seizure_onset        0.013    0.009  1.455 0.146 -0.005  0.032
# age_at_implant             -0.041    0.013 -3.149 0.002 -0.067 -0.016
# session Var                 0.000    0.205
# =====================================================================
#
# Main effect of demographics on number of correct-recalls
# LR test, p value: 178.9252, 0.000000000000000000000000000000
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:            MixedLM Dependent Variable: average_correct_recalls
# No. Observations: 293     Method:             ML
# No. Groups:       90      Scale:              1.4262
# Min. group size:  1       Log-Likelihood:     -467.7599
# Max. group size:  10      Converged:          Yes
# Mean group size:  3.3
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                  -0.488    1.007 -0.485 0.628 -2.462  1.486
# C(gender)[T.Male]          -0.309    0.244 -1.267 0.205 -0.787  0.169
# comb_IQ[T.72.0]             1.272    0.898  1.417 0.156 -0.488  3.032
# comb_IQ[T.73.0]             2.159    0.934  2.311 0.021  0.328  3.989
# comb_IQ[T.74.0]             2.119    0.904  2.344 0.019  0.347  3.891
# comb_IQ[T.75.0]             3.421    0.818  4.179 0.000  1.817  5.025
# comb_IQ[T.76.0]             2.163    0.811  2.667 0.008  0.573  3.753
# comb_IQ[T.77]               3.021    0.954  3.166 0.002  1.151  4.890
# comb_IQ[T.78]               1.605    1.396  1.150 0.250 -1.131  4.341
# comb_IQ[T.79]               1.459    1.060  1.376 0.169 -0.619  3.536
# comb_IQ[T.80]               1.994    0.813  2.454 0.014  0.401  3.586
# comb_IQ[T.81.0]             2.266    0.848  2.671 0.008  0.603  3.928
# comb_IQ[T.83.0]             2.275    0.825  2.757 0.006  0.657  3.892
# comb_IQ[T.84.0]             1.179    0.868  1.358 0.174 -0.522  2.880
# comb_IQ[T.85]               1.560    0.879  1.775 0.076 -0.163  3.282
# comb_IQ[T.86.0]             3.189    0.805  3.960 0.000  1.611  4.768
# comb_IQ[T.87.0]             2.967    0.784  3.784 0.000  1.430  4.503
# comb_IQ[T.89.0]             2.031    0.853  2.381 0.017  0.359  3.704
# comb_IQ[T.91.0]             2.446    1.011  2.420 0.016  0.465  4.428
# comb_IQ[T.92.0]             1.694    0.838  2.022 0.043  0.052  3.337
# comb_IQ[T.94.0]             1.752    0.908  1.929 0.054 -0.028  3.532
# comb_IQ[T.95]               3.347    1.068  3.134 0.002  1.254  5.440
# comb_IQ[T.96.0]             3.169    0.814  3.896 0.000  1.575  4.764
# comb_IQ[T.98.0]             3.513    0.996  3.528 0.000  1.561  5.465
# comb_IQ[T.99.0]             2.212    0.997  2.219 0.026  0.259  4.166
# comb_IQ[T.100.0]            2.597    0.808  3.213 0.001  1.013  4.180
# comb_IQ[T.101.0]            1.383    0.928  1.491 0.136 -0.435  3.202
# comb_IQ[T.102.0]            2.010    0.862  2.332 0.020  0.321  3.700
# comb_IQ[T.103.0]            2.656    0.855  3.108 0.002  0.981  4.331
# comb_IQ[T.104]              1.392    1.080  1.290 0.197 -0.724  3.509
# comb_IQ[T.105.0]            3.392    0.861  3.939 0.000  1.704  5.080
# comb_IQ[T.107.0]            3.047    0.831  3.668 0.000  1.419  4.675
# comb_IQ[T.111.0]            4.935    1.203  4.103 0.000  2.578  7.292
# comb_IQ[T.114.0]            5.134    0.925  5.552 0.000  3.322  6.947
# comb_IQ[T.115.0]            2.961    1.009  2.936 0.003  0.984  4.938
# comb_IQ[T.117.0]            2.509    1.025  2.448 0.014  0.500  4.517
# comb_IQ[T.118.0]            2.915    1.056  2.762 0.006  0.846  4.984
# comb_IQ[T.122.0]            3.296    0.878  3.752 0.000  1.574  5.017
# comb_IQ[T.32 (prorated)]    1.386    1.052  1.318 0.188 -0.675  3.447
# years_of_education          0.220    0.062  3.577 0.000  0.100  0.341
# age_of_seizure_onset        0.013    0.010  1.331 0.183 -0.006  0.032
# age_at_implant             -0.042    0.014 -2.956 0.003 -0.071 -0.014
# BAI                         0.004    0.014  0.278 0.781 -0.024  0.032
# BDI                         0.001    0.013  0.098 0.922 -0.024  0.026
# session Var                 0.000    0.210
# =====================================================================
#
# Main effect of BAI+BDI on correct-recalls, beyond other demographic variables:
# LR test, p value: 0.1368, 0.933897617615999098283907642326
# /home1/evsnyder/.conda/envs/cmlreader0/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
df_master_reduced=df_master.dropna(axis='index',subset=list_demographics_columns)

## Total number of intrusions:
model = sm.MixedLM.from_formula('average_PLI ~ 1',vc_formula=vc,  groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# demographis variables - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_PLI ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of demographics on PLIs')
lr, p = lrtest(llf_empty, llf_demog, df = 5) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


# demographis variables + BDI+BAI - main effect ()
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_PLI ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ + BAI + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI/BAI
print('Main effect of BAI+BDI on PLIs, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: average_PLI
# No. Observations: 148     Method:             ML
# No. Groups:       48      Scale:              0.0800
# Min. group size:  1       Log-Likelihood:     -71.6074
# Max. group size:  7       Converged:          Yes
# Mean group size:  3.1
# ---------------------------------------------------------
#                 Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept       0.461    0.035 13.012 0.000  0.391  0.530
# session Var     0.083    0.157
# =========================================================
#
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:              MixedLM   Dependent Variable:   average_PLI
# No. Observations:   148       Method:               ML
# No. Groups:         48        Scale:                0.0780
# Min. group size:    1         Log-Likelihood:       -63.0382
# Max. group size:    7         Converged:            Yes
# Mean group size:    3.1
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.596    0.392  1.522 0.128 -0.171  1.363
# C(gender)[T.Male]     0.035    0.070  0.496 0.620 -0.102  0.172
# years_of_education   -0.033    0.020 -1.619 0.105 -0.073  0.007
# age_of_seizure_onset  0.005    0.004  1.369 0.171 -0.002  0.012
# age_at_implant        0.009    0.004  2.125 0.034  0.001  0.018
# FSIQ                 -0.002    0.004 -0.342 0.732 -0.010  0.007
# session Var           0.065    0.134
# ===============================================================
#
# Main effect of demographics on PLIs
# LR test, p value: 17.1383, 0.004244827305544123484393193024
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:              MixedLM   Dependent Variable:   average_PLI
# No. Observations:   148       Method:               ML
# No. Groups:         48        Scale:                0.0761
# Min. group size:    1         Log-Likelihood:       -58.4066
# Max. group size:    7         Converged:            Yes
# Mean group size:    3.1
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.297    0.392  0.758 0.449 -0.471  1.064
# C(gender)[T.Male]     0.046    0.074  0.623 0.534 -0.098  0.190
# years_of_education   -0.048    0.022 -2.203 0.028 -0.092 -0.005
# age_of_seizure_onset  0.004    0.004  1.029 0.304 -0.003  0.011
# age_at_implant        0.013    0.004  3.026 0.002  0.005  0.022
# FSIQ                  0.002    0.005  0.504 0.614 -0.007  0.012
# BAI                   0.014    0.005  2.940 0.003  0.005  0.023
# BDI                  -0.010    0.004 -2.224 0.026 -0.019 -0.001
# session Var           0.058    0.122
# ===============================================================
#
# Main effect of BAI+BDI on PLIs, beyond other demographic variables:
# LR test, p value: 9.2633, 0.009738894548725538641287258201

# %%
#Evan's experimental mixed effects models:
list_demographics_columns=['years_of_education','age_of_seizure_onset','age_at_implant','FSIQ','BDI','BAI'] #GAI/FSIQ

# Total number of intrusions
# remove nan's from df:
df_master_reduced=df_master.dropna(axis='index',subset=list_demographics_columns)

## Total number of intrusions:
model = sm.MixedLM.from_formula('average_total_ints ~ 1',vc_formula=vc,  groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# demographis variables - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ average_total_recalls + C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of demographics on total intrusions')
lr, p = lrtest(llf_empty, llf_demog, df = 5) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))

# demographis variables + BDI - main effect ()
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI
print('Main effect of BDI on total intrusions, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))

# demographis variables + BAI - main effect ()
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ + BAI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BAI
print('Main effect of BAI on total intrusions, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))

# demographis variables + total recalls + BDI+BAI - main effect ()
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_total_ints ~ average_total_recalls + C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ + BAI + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI/BAI
print('Main effect of BAI+BDI on total intrusions, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


## Total number of correct-recalls:
model = sm.MixedLM.from_formula('average_correct_recalls ~ 1',vc_formula=vc,  groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_empty =result.llf #log likelihood
print(result.summary())

# demographis variables - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_correct_recalls ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for main effects
print('Main effect of demographics on number of correct-recalls')
lr, p = lrtest(llf_empty, llf_demog, df = 5) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))


# demographis variables + BDI+BAI - main effect
# binary_prior_neuro is 'True' when prior neuro procedure was NOT present, 'False' when any king of procedure WAS present 
model = sm.MixedLM.from_formula('average_correct_recalls ~ C(gender)+C(binary_prior_neuro)+ years_of_education + age_of_seizure_onset + age_at_implant + FSIQ + BAI + BDI',vc_formula=vc, groups='subject', data=df_master_reduced) 
result=model.fit(reml=False, method='nm')
llf_demog_Beck =result.llf #log likelihood
print(result.summary())

# Likelihood ratio tests for BDI/BAI
print('Main effect of BAI+BDI on correct-recalls, beyond other demographic variables:')
lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
# Out:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 148     Method:             ML
# No. Groups:       48      Scale:              0.1991
# Min. group size:  1       Log-Likelihood:     -161.5545
# Max. group size:  7       Converged:          Yes
# Mean group size:  3.1
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      0.929      0.067   13.785   0.000    0.797    1.061
# session Var    0.376      0.398
# ================================================================
#
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 148     Method:             ML
# No. Groups:       48      Scale:              0.2421
# Min. group size:  1       Log-Likelihood:     -150.2030
# Max. group size:  7       Converged:          Yes
# Mean group size:  3.1
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.726    0.730  0.995 0.320 -0.704  2.156
# C(gender)[T.Male]      0.113    0.127  0.888 0.374 -0.136  0.361
# average_total_recalls  0.136    0.044  3.060 0.002  0.049  0.223
# years_of_education    -0.104    0.037 -2.783 0.005 -0.176 -0.031
# age_of_seizure_onset   0.003    0.006  0.523 0.601 -0.009  0.016
# age_at_implant         0.020    0.008  2.502 0.012  0.004  0.035
# FSIQ                   0.002    0.008  0.252 0.801 -0.014  0.018
# session Var            0.226    0.293
# ================================================================
#
# Main effect of demographics on total intrusions
# LR test, p value: 22.7030, 0.000384677390594510013391293946
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: average_total_ints
# No. Observations: 148     Method:             ML
# No. Groups:       48      Scale:              0.1957
# Min. group size:  1       Log-Likelihood:     -152.7184
# Max. group size:  7       Converged:          Yes
# Mean group size:  3.1
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.915    0.760  1.204 0.229 -0.574  2.404
# C(gender)[T.Male]     -0.026    0.144 -0.184 0.854 -0.308  0.255
# years_of_education    -0.124    0.043 -2.908 0.004 -0.208 -0.041
# age_of_seizure_onset   0.008    0.007  1.235 0.217 -0.005  0.022
# age_at_implant         0.019    0.008  2.268 0.023  0.003  0.035
# FSIQ                   0.012    0.010  1.268 0.205 -0.007  0.031
# BDI                   -0.016    0.008 -2.057 0.040 -0.031 -0.001
# session Var            0.306    0.339
# ================================================================
#
# Main effect of BAI on total intrusions, beyond other demographic variables:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-f63635cd1028> in <module>
#      33 # Likelihood ratio tests for BDI
#      34 print('Main effect of BAI on total intrusions, beyond other demographic variables:')
# ---> 35 lr, p = lrtest(llf_demog, llf_demog_Beck, df = 2) # Degrees of freedom = number of regressors (i.e. columns in summary table) added when including the effect of interest, for categorical variable with two groups this is df = 1
#      36 print('LR test, p value: {:.4f}, {:.30f}'.format(lr, p))
#      37
#
# <ipython-input-9-0de0bfb2ade2> in lrtest(llmin, llmax, df)
#       6     lr = 2 * (llmax - llmin)
#       7     if llmax<llmin:
# ----> 8         raise ValueError('Check assumptions.')
#       9     stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
#      10     p = stats.chisqprob(lr, df)
#
# ValueError: Check assumptions.
